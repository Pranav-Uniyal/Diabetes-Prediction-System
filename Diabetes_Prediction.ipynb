# %% [markdown]
# System Specifications

# %% [markdown]
# Importing the Libraries Required

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis

# %%
# loading the diabetes dataset to pandas dataframe
diabetes_set = pd.read_csv('/content/diabetes.csv')

# %%
# printing 1st five rows of dataset
diabetes_set.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0             6      148             72  ...                     0.627   50        1
# 1             1       85             66  ...                     0.351   31        0
# 2             8      183             64  ...                     0.672   32        1
# 3             1       89             66  ...                     0.167   21        0
# 4             0      137             40  ...                     2.288   33        1
# 5             5      116             74  ...                     0.201   30        0
# 6             3       78             50  ...                     0.248   26        1
# 7            10      115              0  ...                     0.134   29        0
# 8             2      197             70  ...                     0.158   53        1
# 9             8      125             96  ...                     0.232   54        1
# 10            4      110             92  ...                     0.191   30        0
# 11           10      168             74  ...                     0.537   34        1
# 12           10      139             80  ...                     1.441   57        0
# 13            1      189             60  ...                     0.398   59        1
# 14            5      166             72  ...                     0.587   51        1
# 15            7      100              0  ...                     0.484   32        1
# 16            0      118             84  ...                     0.551   31        1
# 17            7      107             74  ...                     0.254   31        1
# 18            1      103             30  ...                     0.183   33        0
# 19            1      115             70  ...                     0.529   32        1
#
# [20 rows x 9 columns]

# %%
# Number of rows and columns from this dataset table
diabetes_set.shape
# Out:
# (768, 9)

# %%
# getting the statistical measures
diabetes_set.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  ...  DiabetesPedigreeFunction         Age     Outcome
# count   768.000000  768.000000     768.000000  ...                768.000000  768.000000  768.000000
# mean      3.845052  120.894531      69.105469  ...                  0.471876   33.240885    0.348958
# std       3.369578   31.972618      19.355807  ...                  0.331329   11.760232    0.476951
# min       0.000000    0.000000       0.000000  ...                  0.078000   21.000000    0.000000
# 25%       1.000000   99.000000      62.000000  ...                  0.243750   24.000000    0.000000
# 50%       3.000000  117.000000      72.000000  ...                  0.372500   29.000000    0.000000
# 75%       6.000000  140.250000      80.000000  ...                  0.626250   41.000000    1.000000
# max      17.000000  199.000000     122.000000  ...                  2.420000   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
diabetes_set['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 -> Non Diabetic
#
# 1 -> Diabetic

# %%
diabetes_set.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  ...        BMI  DiabetesPedigreeFunction        Age
# Outcome                                          ...
# 0           3.298000  109.980000      68.184000  ...  30.304200                  0.429734  31.190000
# 1           4.865672  141.257463      70.824627  ...  35.142537                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
# Separating data and label
x=diabetes_set.drop(columns='Outcome',axis=1)
y=diabetes_set['Outcome']
print(x)
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# 767            1       93             70  ...  30.4                     0.315   23
#
# [768 rows x 8 columns]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler=StandardScaler()
scaler.fit(x)
sdata=scaler.transform(x)
print(sdata)
import joblib
# Save the fitted scaler
joblib.dump(scaler, 'diabetes_scaler.pkl')
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# ['diabetes_scaler.pkl']

# %%
x=sdata
y=diabetes_set['Outcome']
print(x)
print(y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Train Test split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)
print(x.shape,xtrain.shape,xtest.shape)#20% test 80% train
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Training the Model

# %%
classifier =svm.SVC(kernel='linear')
#training the support vector machine classifier
classifier.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# accuracy score

# %%
#Accuracy score on Training data
xtrain_acc_prediction=classifier.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)

# %%
print('Accuracy Score of training data:',training_data_acc)
# Out:
# Accuracy Score of training data: 0.7866449511400652

# %%
#Accuracy score on Test data
xtest_acc_prediction=classifier.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of test data: 0.7727272727272727

# %% [markdown]
# Making a Prediction System

# %%
from sklearn.linear_model import LogisticRegression
regressor=LogisticRegression()
regressor.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
xtrain_acc_prediction=regressor.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)
# Out:
# Accuracy Score of training data: 0.7850162866449512

# %%
#Accuracy score on Test data
xtest_acc_prediction=regressor.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of test data: 0.7597402597402597

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
model.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xtrain_acc_prediction=model.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 1.0
# Accuracy Score of test data: 0.7402597402597403

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()
model.fit(xtrain,ytrain)

xtrain_acc_prediction=model.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 1.0
# Accuracy Score of test data: 0.7142857142857143

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()
model1.fit(xtrain,ytrain)

xtrain_acc_prediction=model1.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model1.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 1.0
# Accuracy Score of test data: 0.7272727272727273

# %%
from sklearn.neighbors import KNeighborsClassifier
model2=KNeighborsClassifier()
model2.fit(xtrain,ytrain)

xtrain_acc_prediction=model2.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model2.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 0.8289902280130294
# Accuracy Score of test data: 0.7207792207792207

# %%
from sklearn.neural_network import MLPClassifier
model3=MLPClassifier()
model3.fit(xtrain,ytrain)
xtrain_acc_prediction=model3.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model3.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 0.8192182410423453
# Accuracy Score of test data: 0.7662337662337663
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.naive_bayes import GaussianNB
model4=GaussianNB()
model4.fit(xtrain,ytrain)
xtrain_acc_prediction=model4.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model4.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 0.755700325732899
# Accuracy Score of test data: 0.7727272727272727

# %%
from sklearn.ensemble import GradientBoostingClassifier
model5=GradientBoostingClassifier()
model5.fit(xtrain,ytrain)
xtrain_acc_prediction=model5.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model5.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 0.9250814332247557
# Accuracy Score of test data: 0.7012987012987013

# %%
from sklearn.ensemble import AdaBoostClassifier
model6=AdaBoostClassifier()
model6.fit(xtrain,ytrain)
xtrain_acc_prediction=model6.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model6.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 0.8045602605863192
# Accuracy Score of test data: 0.7272727272727273

# %%
from sklearn.ensemble import BaggingClassifier
model7=BaggingClassifier()
model7.fit(xtrain,ytrain)
xtrain_acc_prediction=model7.predict(xtrain)
training_data_acc=accuracy_score(xtrain_acc_prediction,ytrain)
print('Accuracy Score of training data:',training_data_acc)

#Accuracy score on Test data
xtest_acc_prediction=model7.predict(xtest)
test_data_acc=accuracy_score(xtest_acc_prediction,ytest)
print('Accuracy Score of test data:',test_data_acc)
# Out:
# Accuracy Score of training data: 0.9853420195439739
# Accuracy Score of test data: 0.7207792207792207

# %%
input_data=(6	,148,	72,	35,	0,	33.6,	0.627,	50)
#convert input dat to numpy array
ind=np.asarray(input_data)
#reshape of array as we re predicting for one instance
ind_reshape=ind.reshape(1,-1)
#Standardize the input data to work
std_data=scaler.transform(ind_reshape)
print(std_data)
#prediction
prediction=classifier.predict(std_data)
print(prediction)
if(prediction[0]==0):
  print('The Person is Non-Diabetic')
else:
  print('The Person is Diabetic')
# Out:
# [[ 0.63994726  0.84832379  0.14964075  0.90726993 -0.69289057  0.20401277
#    0.46849198  1.4259954 ]]
# [1]
# The Person is Diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(xtrain.shape[1],)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(xtrain, ytrain, epochs=50, batch_size=32, validation_data=(xtest, ytest))

_, test_acc = model.evaluate(xtest, ytest)
print("Neural Network Accuracy:", test_acc)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5120 - loss: 0.6879 - val_accuracy: 0.7403 - val_loss: 0.5892
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7816 - loss: 0.5502 - val_accuracy: 0.7662 - val_loss: 0.5312
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7723 - loss: 0.4954 - val_accuracy: 0.7597 - val_loss: 0.5185
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7847 - loss: 0.4567 - val_accuracy: 0.7532 - val_loss: 0.5196
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7921 - loss: 0.4409 - val_accuracy: 0.7597 - val_loss: 0.5205
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7883 - loss: 0.4446 - val_accuracy: 0.7532 - val_loss: 0.5239
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7923 - loss: 0.4194 - val_accuracy: 0.7662 - val_loss: 0.5271
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7726 - loss: 0.4333 - val_accuracy: 0.7662 - val_loss: 0.5383
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8175 - loss: 0.3991 - val_accuracy: 0.7403 - val_loss: 0.5346
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8290 - loss: 0.3806 - val_accuracy: 0.7597 - val_loss: 0.5359
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7958 - loss: 0.4055 - val_accuracy: 0.7597 - val_loss: 0.5371
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8152 - loss: 0.4095 - val_accuracy: 0.7662 - val_loss: 0.5409
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8146 - loss: 0.3879 - val_accuracy: 0.7662 - val_loss: 0.5443
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8129 - loss: 0.3829 - val_accuracy: 0.7532 - val_loss: 0.5479
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.4034 - val_accuracy: 0.7403 - val_loss: 0.5483
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8030 - loss: 0.3850 - val_accuracy: 0.7662 - val_loss: 0.5381
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7955 - loss: 0.4032 - val_accuracy: 0.7532 - val_loss: 0.5427
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8412 - loss: 0.3514 - val_accuracy: 0.7662 - val_loss: 0.5499
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8123 - loss: 0.3898 - val_accuracy: 0.7468 - val_loss: 0.5508
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8364 - loss: 0.3646 - val_accuracy: 0.7403 - val_loss: 0.5567
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8219 - loss: 0.3682 - val_accuracy: 0.7468 - val_loss: 0.5615
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8440 - loss: 0.3515 - val_accuracy: 0.7338 - val_loss: 0.5580
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8169 - loss: 0.3733 - val_accuracy: 0.7662 - val_loss: 0.5600
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8115 - loss: 0.3730 - val_accuracy: 0.7273 - val_loss: 0.5786
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8280 - loss: 0.3588 - val_accuracy: 0.7338 - val_loss: 0.5726
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8350 - loss: 0.3364 - val_accuracy: 0.7273 - val_loss: 0.5802
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8252 - loss: 0.3754 - val_accuracy: 0.7403 - val_loss: 0.5788
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8604 - loss: 0.3169 - val_accuracy: 0.7403 - val_loss: 0.5796
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8472 - loss: 0.3386 - val_accuracy: 0.7338 - val_loss: 0.5839
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8491 - loss: 0.3300 - val_accuracy: 0.7403 - val_loss: 0.5880
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8448 - loss: 0.3422 - val_accuracy: 0.7532 - val_loss: 0.5962
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8476 - loss: 0.3535 - val_accuracy: 0.7338 - val_loss: 0.6115
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8607 - loss: 0.3238 - val_accuracy: 0.7273 - val_loss: 0.6015
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8610 - loss: 0.3361 - val_accuracy: 0.7403 - val_loss: 0.6113
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8649 - loss: 0.3245 - val_accuracy: 0.7273 - val_loss: 0.6137
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8482 - loss: 0.3406 - val_accuracy: 0.7338 - val_loss: 0.6232
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8495 - loss: 0.3239 - val_accuracy: 0.7468 - val_loss: 0.6146
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8624 - loss: 0.3238 - val_accuracy: 0.7338 - val_loss: 0.6414
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8797 - loss: 0.2870 - val_accuracy: 0.7338 - val_loss: 0.6469
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8491 - loss: 0.3281 - val_accuracy: 0.7273 - val_loss: 0.6407
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8589 - loss: 0.2998 - val_accuracy: 0.7468 - val_loss: 0.6460
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8694 - loss: 0.3124 - val_accuracy: 0.7338 - val_loss: 0.6484
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8796 - loss: 0.3032 - val_accuracy: 0.7338 - val_loss: 0.6595
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8734 - loss: 0.3069 - val_accuracy: 0.7403 - val_loss: 0.6518
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9051 - loss: 0.2731 - val_accuracy: 0.7273 - val_loss: 0.6880
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 0.2560 - val_accuracy: 0.7338 - val_loss: 0.6597
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.2965 - val_accuracy: 0.6883 - val_loss: 0.7070
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8948 - loss: 0.2823 - val_accuracy: 0.7273 - val_loss: 0.6855
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8894 - loss: 0.2897 - val_accuracy: 0.7078 - val_loss: 0.7040
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8634 - loss: 0.2881 - val_accuracy: 0.7273 - val_loss: 0.6978
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7390 - loss: 0.7012
# Neural Network Accuracy: 0.7272727489471436

# %%
# !pip install tpot
from tpot import TPOTClassifier

tpot = TPOTClassifier(generations=5, population_size=50, verbosity=2, random_state=42)
tpot.fit(xtrain, ytrain)

print("Best Model Found by TPOT:", tpot.fitted_pipeline_)
print("AutoML Accuracy:", tpot.score(xtest, ytest))
# Out:
# Collecting tpot
#   Downloading TPOT-0.12.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.6.1)
# Collecting deap>=1.2 (from tpot)
#   Downloading deap-1.4.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting update-checker>=0.16 (from tpot)
#   Downloading update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from tpot) (4.67.1)
# Collecting stopit>=1.1.1 (from tpot)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from tpot) (2.2.2)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from tpot) (1.4.2)
# Requirement already satisfied: xgboost>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tpot) (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->tpot) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->tpot) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.1->tpot) (3.5.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from update-checker>=0.16->tpot) (2.32.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost>=1.1.0->tpot) (2.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->tpot) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2025.1.31)
# Downloading TPOT-0.12.2-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 5.8 MB/s eta 0:00:00
# Downloading deap-1.4.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 9.0 MB/s eta 0:00:00
# Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=6208711756f2255e3bbd743b31183d083492fdc34a14000eafa867ca96a36b59
#   Stored in directory: /root/.cache/pip/wheels/da/77/2d/adbc56bc4db95ad80c6d4e71cd69e2d9d122174904342e3f7f
# Successfully built stopit
# Installing collected packages: stopit, deap, update-checker, tpot
# Successfully installed deap-1.4.2 stopit-1.1.2 tpot-0.12.2 update-checker-0.18.0
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_classifier
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1230: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1270: FutureWarning: passing a class to None is deprecated and will be removed in 1.8. Use an instance of the class instead.
#   warnings.warn(
# is_classifier
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# is_classifier
# is_classifier
# is_regressor
# is_classifier
# is_regressor
# is_classifier
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.7817273090763694
#
# Generation 2 - Current best internal CV score: 0.7817273090763694
#
# Generation 3 - Current best internal CV score: 0.7866053578568573
#
# Generation 4 - Current best internal CV score: 0.7866053578568573
#
# Generation 5 - Current best internal CV score: 0.7866053578568573
#
# Best pipeline: RandomForestClassifier(input_matrix, bootstrap=False, criterion=entropy, max_features=0.35000000000000003, min_samples_leaf=8, min_samples_split=11, n_estimators=100)
# Best Model Found by TPOT: Pipeline(steps=[('randomforestclassifier',
#                  RandomForestClassifier(bootstrap=False, criterion='entropy',
#                                         max_features=0.35000000000000003,
#                                         min_samples_leaf=8,
#                                         min_samples_split=11,
#                                         random_state=42))])
# AutoML Accuracy: 0.7532467532467533

# %%
import joblib # Import the joblib library

joblib.dump(classifier, 'diabetes_model.pkl')
# Out:
# ['diabetes_model.pkl']
